# %% [markdown]
# # Act Report
#
# ## We Rate Dogs Twitter Dataset Wrangling Report
#
# - This analysis utilized some analytical techniques to discuss significant findings and visualizations from a cleaned Twitter archive data dataset.
# - People may be confused on the breed of dogs to buy due to the numerous breeds we have in town today. This can be a dicey decision but I have helped to respond to this dilema in this section.
# - Four questions are thereby illustrated in the analysis;
#
#
# > 1. which dog development stage is the most common <br>
# > 2. What's the most pupolar dog names <br>
# > 3. The most common dog breed <br>
# > 4. What's is the correlation between dog ratings and number of retweets

# %% [markdown]
# ### 1. Which dog development stage is the most common.
# - A bar graph is used to answer this question

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Dogs without any category of development stage has the most occurence from bar chart above

# %% [markdown]
# ### 2. What's the most pupolar dog names
# - A bar graph is used to answer this question

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# name 'a' is the most common of all the dog names in the data

# %% [markdown]
# ### 3. The most common dog breed
# - A bar graph is used to answer this question

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <b>Dumber</b> is the most common dog breed followed by <b>Brabancon_griffon</b>

# %% [markdown]
# ### 4. What's is the correlation between dog ratings and number of retweets
# - A scattered plot is used to answer this question

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# From the chart above, it is seen that the dog with the highest number of rating does not have the highest number of retweet. This implies that retweets may not be considered when when choosing to buy a dog.
